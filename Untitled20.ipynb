# %%
#Calculator

print("""
1. Addition
2. Subtraction
3. Multiplication
4. Division
5.Exit
""")

try:
    choice = input("Enter the number: ")
    if choice == "5":
        print("Exiting Goodbye!")


    elif choice == "1":
        try:
            num1 = float(input("Enter the first number: "))
            num2 = float(input("Enter the second number: "))
            print("The output is:", num1 + num2)
        except ValueError:
            print("Error: Please enter valid numbers.")

    elif choice == "2":
        try:
            num1 = float(input("Enter the first number: "))
            num2 = float(input("Enter the second number: "))
            print("The output is:", num1 - num2)
        except ValueError:
            print("Error: Please enter valid numbers.")

    elif choice == "3":
        try:
            num1 = float(input("Enter the first number: "))
            num2 = float(input("Enter the second number: "))
            print("The output is:", num1 * num2)
        except ValueError:
            print("Error: Please enter valid numbers.")

    elif choice == "4":
        try:
            num1 = float(input("Enter the first number: "))
            num2 = float(input("Enter the second number: "))
            if num2 == 0:
                print("Error: Division by zero is not allowed.")
            else:
                print("The output is:", num1 / num2)
        except ValueError:
            print("Error: Please enter valid numbers.")

    else:
        print("The input is invalid.")

except Exception as e:
    print("Unexpected error occurred:", e)
# Out:
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5.Exit
# Enter the number:  3
# Enter the first number:  45
# Enter the second number:  98
# The output is: 4410.0

# %%
#MOVIE TICKET BOOKING
#if else condition in python

age=int(input("enter a number:"))
if age>=18 :
    print("you can have movie ticket and watch movie")
else:
    print("watch movie with parents")
# Out:
# enter a number: 23
# you can have movie ticket and watch movie

# %%
#NEGATIVE POSITIVE CHECKER

num=int(input("enter a number:"))
if num>=0 :
    print("number is Positive")
else:
    print("number is Negative")
# Out:
# enter a number: 23
# number is Positive

# %%
#ATM Pin
balance= 80000
pin=2301

attempts=0
while attempts < 3 :
    user_pin=int(input("enter the pin :"))
    if user_pin==pin :
        print(" your balance is :",balance)
        amount=int(input("the amount for withdrawl :"))
        balance-=amount
        print("congrats you withdrwed the amount :")
        print("new balance is :",balance)
        break 
    else : 
        print("the input is invalid :")
        attempts +=1

    if attempts == 3:
        print("your access is denied :")
# Out:
# enter the pin : 3456
# the input is invalid :
# enter the pin : 2301
#  your balance is : 80000
# the amount for withdrawl : 789
# congrats you withdrwed the amount :
# new balance is : 79211

# %%
#Unit Converter
k=float(input("enter a number"))
km=float(input("enter a number"))
Kilograms=float(input("enter a number"))
f=k*(9/5)+32
meter=1000*km
Pounds = Kilograms * 2.20462
print("f",f)
print("meter",meter)
print("pounds",Pounds)
# Out:
# enter a number 87
# enter a number 98
# enter a number 89
# f 188.6
# meter 98000.0
# pounds 196.21117999999998

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#Graph student hrs vs marks
import matplotlib.pyplot as plt
subject= (1,2,3,4,5)
marks= (10,20,30,40,50)
plt.plot(subject,marks)
plt.title("Student hrs vs marks")
plt.xlabel("subject")
plt.ylabel("marks")
plt.show()

# %%
#Bar Graph
import matplotlib.pyplot as plt
subject = ["M1", "M2", "CHEM", "Physics"]
marks = ["15", "14" ,"16" ,"25"]

plt.bar(subject,marks)
plt.title("subject vs marks ")
plt.xlabel("SUB")
plt.ylabel("Marks")
plt.show()

# %%
pip install pyttsx3
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pyttsx3

# %%
#Text to speech python application for voice assistace
speaker = pyttsx3.init()
speaker.say("welcome dheeraj sir")
speaker.runAndWait()

# %%
pip install SpeechRecognition pyaudio
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import speech_recognition as sr

# %%
mic = sr.Recognizer()

# %%
#Speaktotext python project
with sr.Microphone() as source:
    print("Start Speaking,,,,")
    voice = mic.listen(source)
    text = mic.recognize_google(voice)
    print("You said this : ",text)
# Out:
# Start Speaking,,,,
# You said this :  copy kar diya what the fuck my

# %%
pip install pywhatkit
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pywhatkit

# %%
      #Automated Whatsapp Messaging System using Python
pywhatkit.sendwhatmsg_instantly("+918306672163" , "Hi am from VGU ", )

# %%
pywhatkit.sendwhatmsg("+918306672163" , "Hi am from VGU ",14,48 )

# %%
import webbrowser

# %%
webbrowser.open_new_tab("http://lms.hash13.com/")

# %%
#Speech Recognition
import matplotlib.pyplot as plt
import pyttsx3
import os
import webbrowser
import speech_recognition as sr
import pywhatkit

speaker = pyttsx3.init('sapi5')
mic = sr.Recognizer()

speaker.say("Welcome to Bixby")
speaker.runAndWait()

with sr.Microphone() as source:
    print("Start speaking...")
    mic.adjust_for_ambient_noise(source, duration=1)

    try:
        voice = mic.listen(source, timeout=5, phrase_time_limit=5)
        text = mic.recognize_google(voice)
        command = text.lower()
        print("You said:", command)

    except sr.WaitTimeoutError:
        print("No speech detected.")
        command = ""
    except sr.UnknownValueError:
        print("Sorry, I could not understand.")
        command = ""
    except sr.RequestError:
        print("Speech service down.")
        command = ""



if "notepad" in command or "note pad" in command:
    print("Opening Notepad...")
    os.system("notepad")

elif "youtube" in command or "you tube" in command or "yt" in command:
    print("Opening YouTube...")
    webbrowser.open("https://youtube.com")

elif "spotify" in command or "spot fy" in command or "spootify" in command:
    print("Opening Spotify...")
    try:
        os.system("start spotify")
    except:
        webbrowser.open("https://open.spotify.com")
        print("Spotify Desktop not found — opening web player.")

elif "whatsapp" in command or "send message" in command:
    print("Sending WhatsApp message...")
    try:
        pywhatkit.sendwhatmsg_instantly(
            "+919548892134",
            "hi i am from vgu",
            wait_time=10,
            tab_close=True
        )
        print("Message sent!")
    except Exception as e:
        print("Error sending WhatsApp message:", e)

elif command != "":
    print("Command not recognized.")

speaker.stop()
import matplotlib.pyplot as plt
import pyttsx3
import os
import webbrowser
import speech_recognition as sr
import pywhatkit

speaker = pyttsx3.init('sapi5')
mic = sr.Recognizer()

speaker.say("Welcome to Bixby")
speaker.runAndWait()

with sr.Microphone() as source:
    print("Start speaking...")
    mic.adjust_for_ambient_noise(source, duration=1)

    try:
        voice = mic.listen(source, timeout=5, phrase_time_limit=5)
        text = mic.recognize_google(voice)
        command = text.lower()
        print("You said:", command)

    except sr.WaitTimeoutError:
        print("No speech detected.")
        command = ""
    except sr.UnknownValueError:
        print("Sorry, I could not understand.")
        command = ""
    except sr.RequestError:
        print("Speech service down.")
        command = ""


if "notepad" in command or "note pad" in command:
    print("Opening Notepad...")
    os.system("notepad")

elif "youtube" in command or "you tube" in command or "yt" in command:
    print("Opening YouTube...")
    webbrowser.open("https://youtube.com")

elif "spotify" in command or "spot fy" in command or "spootify" in command:
    print("Opening Spotify...")
    try:
        os.system("start spotify")
    except:
        webbrowser.open("https://open.spotify.com")
        print("Spotify Desktop not found — opening web player.")

elif "whatsapp" in command or "send message" in command:
    print("Sending WhatsApp message...")
    try:
        pywhatkit.sendwhatmsg_instantly(
            "+919548892134",
            "hi i am from vgu",
            wait_time=10,
            tab_close=True
        )
        print("Message sent!")
    except Exception as e:
        print("Error sending WhatsApp message:", e)

elif command != "":
    print("Command not recognized.")

speaker.stop()

# %%
#resume from flask api 
from flask import Flask
app = Flask(__name__)

@app.route("/")
def home():
    return """

<!DOCTYPE html>
<html lang="en">
<head>
<meta charset="UTF-8" />
<meta name="viewport" content="width=device-width, initial-scale=1.0" />
<title>My Resume</title>
<style>
body {
font-family: Arial, sans-serif;
margin: 40px;
background: #f4f4f4;
}
.container {
max-width: 800px;
margin: auto;
background: #fff;
padding: 30px;
border-radius: 10px;
box-shadow: 0 0 10px rgba(0,0,0,0.1);
}
h1, h2 {
color: #333;
}
.section {
margin-bottom: 25px;
}
.section-title {
border-bottom: 2px solid #333;
padding-bottom: 5px;
margin-bottom: 10px;
}
ul {
margin: 0;
padding-left: 20px;
}
</style>
</head>
<body>
<div class="container">
<h1>Your Name</h1>
<p><strong>Email:</strong> your.email@example.com</p>
<p><strong>Phone:</strong> +91 XXXXX XXXXX</p>
<p><strong>Address:</strong> Your City, India</p>

<div class="section">
<h2 class="section-title">Career Objective</h2>
<p>Write your career objective here.</p>
</div>

<div class="section">
<h2 class="section-title">Education</h2>
<ul>
<li><strong>Degree Name</strong> – College Name (Year)</li>
<li><strong>12th Grade</strong> – School Name (Year)</li>
<li><strong>10th Grade</strong> – School Name (Year)</li>
</ul>
</div>

<div class="section">
<h2 class="section-title">Skills</h2>
<ul>
<li>Python, HTML, CSS</li>
<li>Machine Learning Basics</li>
<li>Problem Solving</li>
</ul>
</div>

<div class="section">
<h2 class="section-title">Projects</h2>
<ul>
<li><strong>Project Title</strong> – Description of your project.</li>
<li><strong>Project Title</strong> – Description of another project.</li>
</ul>
</div>

<div class="section">
<h2 class="section-title">Experience</h2>
<p>If you have experience, add it here. If not, remove this section.</p>
</div>

<div class="section">
<h2 class="section-title">Languages</h2>
<ul>
<li>English</li>
<li>Hindi</li>
</ul>
</div>

</div>
</body>
</html>

"""

if __name__ == "__main__":
    app.run(debug=True)

# %%
#XO Game
import pygame
pygame.init()

screen = pygame.display.set_mode((600, 600))
pygame.display.set_caption("X/O GAME")

WHITE = (255, 255, 255)
BLACK = (0, 0, 0)

board = [["", "", ""],
         ["", "", ""],
         ["", "", ""]]

player = "X"
font = pygame.font.Font(None, 150)

run = True
while run:
    screen.fill(WHITE)

    # Draw grid lines
    pygame.draw.line(screen, BLACK, (200, 0), (200, 600), 5)
    pygame.draw.line(screen, BLACK, (400, 0), (400, 600), 5)
    pygame.draw.line(screen, BLACK, (0, 200), (600, 200), 5)
    pygame.draw.line(screen, BLACK, (0, 400), (600, 400), 5)

    # Draw X and O on the board
    for row in range(3):
        for col in range(3):
            if board[row][col] != "":
                text = font.render(board[row][col], True, BLACK)
                screen.blit(text, (col * 200 + 50, row * 200 + 20))

    # Event handling
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            run = False

        if event.type == pygame.MOUSEBUTTONDOWN:
            mouse_x, mouse_y = pygame.mouse.get_pos()
            row = mouse_y // 200
            col = mouse_x // 200

            if board[row][col] == "":
                board[row][col] = player
                player = "O" if player == "X" else "X"  # switch player

    pygame.display.update()

pygame.quit()
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.13.5)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
#Chatbot AI
import google.generativeai as genai
key = "AIzaSyD9Q7n8WiPL3K6GJgV7dufNzQD5ZOxd0Vk"

print (key)

genai.configure(api_key=key)

model = genai.GenerativeModel ("gemini-2.5-flash")

while True:
    user = input("Enter what you want to search or type exist to close")
    if user.lower() == "exit":
        print("bye bye")
        break
        response = model.generate_content(user)
        print("BOT :", response.text)
# Out:
# AIzaSyD9Q7n8WiPL3K6GJgV7dufNzQD5ZOxd0Vk
# Enter what you want to search or type exist to close what is the capital of india
# Enter what you want to search or type exist to close exit
# bye bye

# %%
#STREAMLIT DASHBOARD

import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt

st.title("Streamlit app of vgu")
st.text("Welcome to our dashboard")
st.header("I am a header")
st.write("You can write", 20 + 5)

name = st.text_input("Enter your name:")
age = st.number_input("Enter your age:")

st.write("Your name is:", name, "Your age is:", age)
st.selectbox("Enter your course :", ["BCA", "Btech", "MCA"])
if st.button("Click ME"):
    st.success("Clicked Button")
file = st.file_uploader("Upload your file")
if file:
    content = file.read()
    st.write("File Uploaded Successfully !!!")

data = {"Name":["TOM","Jack", "POP", "Harry"], "Marks" : [10,20,20,10] }
df = pd.DataFrame(data)

st.dataframe(df)

data = pd.DataFrame({
    "Marks" : [10,20,20,10]

})

st.line_chart(data)
st.bar_chart(data)

subject = ["Python", "c++", "java"]
marks = [20,10,5]

fig, ax = plt.subplots()
ax.pie(marks, labels=subject,autopct= '%1.1f%%')
st.pyplot(fig)
